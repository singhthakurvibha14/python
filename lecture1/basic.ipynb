# %%
print("hello")
# Out:
# hello

# %%
print("hello world!")
# Out:
# hello world!

# %%
print(12+3,12-3,12*3,12/7)
# Out:
# 15 9 36 1.7142857142857142

# %%
x=5
y=7
z=5
print(id(x) , id(y) , id(z))   #here this id will show the address of the variable
# Out:
# 140705850107128 140705850107192 140705850107128

# %%
name = input("enter the name")
print (name)
age = input ("enter your age")
print(age)
height = float(input("enter height"))
print(height)
# Out:
# vibha
# 20
# 5.4

# %%
print("vibha singh thakur")
# Out:
# vibha singh thakur
