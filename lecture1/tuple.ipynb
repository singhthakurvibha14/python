# %%
#Empty Tuple creation
tpl=()
tpl1=tuple()
print(tpl , tpl1)
# Out:
# () ()

# %%
#type of tuple
tpl=(1)
print(type(tpl))
# Out:
# <class 'int'>

# %%
#deletion of tuple

tpl=1,"hello",2,3
# del tpl   (it will give us error )

print(tpl)
# Out:
# (1, 'hello', 2, 3)

# %%
tpl=(2,3,4,"hello",6)
print(id(tpl))
tpl+=(7,8,9)   
print(id(tpl))
# Out:
# 2416154201824
# 2416152903152

# %%
tpl = (2,3,4,5,6,"hello")
tpl=list(tpl)
tpl[3]=90
tpl=tuple(tpl)
print(tpl)
# Out:
# (2, 3, 4, 90, 6, 'hello')

# %%
tpl=(1,2,5,6,7,8,3,10)
# print(sorted(tpl,reverse=True))
print(sorted(tpl))
# Out:
# [1, 2, 3, 5, 6, 7, 8, 10]

# %%
tpl=(1,5,6,4,3,6,7,7,77,1,2)
tpl[-3::-6]
# Out:
# (77, 6)

# %%
#another way for creation of tuple
tpl=1,"hello"
print(type(tpl))
# Out:
# <class 'tuple'>
